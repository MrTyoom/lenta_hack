# %%
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForImageTextToText
from qwen_vl_utils import process_vision_info

model_id = r"C:\Users\GGamers\Desktop\FLC\hackhatons\lenta\AVITO"

# Модель и процессор
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    torch_dtype="auto",
    device_map="auto",
)
processor = AutoProcessor.from_pretrained(model_id)

img = Image.open("lenta_hack-as-branch\data\crop1.png")  # выберите локально загруженное изображение

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": img,
                "min_pixels": 4 * 28 * 28,
                "max_pixels": 1024 * 28 * 28,
            },
            {
                "type": "text",
                "text": """
                Напиши название товара, оно находится в верхней части слева
                Изучи ценник товара, твоя задача определить его
                название, цену без карты цена по карте
                , если есть какие-то дополнительные скидочные условия описать
                  так же их и найти артикул, перед артикулом стоит
                    знак _ так же есть штрихкод нужен его код"""
            }
        ],
    }
]

# Подготовка входа
chat_text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[chat_text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)

inputs = inputs.to("cuda")

# Генерация
generated_ids = model.generate(**inputs, max_new_tokens=256)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
response = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(response)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\d'
# <>:16: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\GGamers\AppData\Local\Temp\ipykernel_23400\1415243490.py:16: SyntaxWarning: invalid escape sequence '\d'
#   img = Image.open("lenta_hack-as-branch\data\crop1.png")  # выберите локально загруженное изображение
# Loading weights: 100%|██████████| 729/729 [00:01<00:00, 508.52it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# systemYouareahelpfulassistant.user�з����енн�к�ова�а,�воязада�аоп�едел���егоназван�е,�ен�безка����енапока��е,е�л�е���как�е-�одополн��ел�н�е�к�до�н�е��лов�яоп��а���акже���най��а���к�л,пе�еда���к�лом��о��знак_�акжее��������кодн�женегокодassistant<0x0A>На▁изображении▁представлена▁ценник▁на▁товар▁с▁указанием▁скидки▁17%.▁Цена▁товара▁составляет▁329.99▁рублей.▁Также▁указана▁информация▁о▁банке▁и▁торговой▁точке,▁где▁был▁куплен▁товар.

# %%
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForImageTextToText
from qwen_vl_utils import process_vision_info
model_id = r"C:\Users\GGamers\Desktop\FLC\hackhatons\lenta\AVITO"
# Модель и процессор - без device_map, вручную перенесем на GPU
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,  # родной dtype модели
)
processor = AutoProcessor.from_pretrained(model_id)
# Переносим на GPU после загрузки
model = model.to('cuda')


processor = AutoProcessor.from_pretrained(model_id)

img = Image.open("lenta_hack-as-branch\data\crop1.png")  # выберите локально загруженное изображение

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": img,
                "min_pixels": 4 * 28 * 28,
                "max_pixels": 1024 * 28 * 28,
            },
            {
                "type": "text",
                "text": """
                Напиши название товара, оно находится в верхней части слева
                Изучи ценник товара, твоя задача определить его
                название, цену без карты цена по карте
                , если есть какие-то дополнительные скидочные условия описать
                  так же их и найти артикул, перед артикулом стоит
                    знак _ так же есть штрихкод нужен его код"""
            }
        ],
    }
]

# Подготовка входа
chat_text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[chat_text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)

inputs = inputs.to("cuda")

# Генерация
generated_ids = model.generate(**inputs, max_new_tokens=256)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
response = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(response)
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\d'
# <>:18: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\GGamers\AppData\Local\Temp\ipykernel_23400\762463440.py:18: SyntaxWarning: invalid escape sequence '\d'
#   img = Image.open("lenta_hack-as-branch\data\crop1.png")  # выберите локально загруженное изображение
# Loading weights: 100%|██████████| 729/729 [00:00<00:00, 10238.88it/s]
# systemYouareahelpfulassistant.user�з����енн�к�ова�а,�воязада�аоп�едел���егоназван�е,�ен�безка����енапока��е,е�л�е���как�е-�одополн��ел�н�е�к�до�н�е��лов�яоп��а���акже���най��а���к�л,пе�еда���к�лом��о��знак_�акжее��������кодн�женегокодassistant<0x0A>На▁изображении▁представлена▁ценник▁с▁информацией▁о▁скидке▁и▁цене▁товара.▁Цена▁указана▁как▁329.99▁рублей,▁что▁соответствует▁17%▁скидки▁от▁первоначальной▁стоимости.▁Также▁на▁ценнике▁указаны▁логотип▁магазина▁"Магнит"▁и▁QR-код▁для▁дополнительной▁информации.

# %%
import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForImageTextToText
from qwen_vl_utils import process_vision_info

model_id = r"C:\Users\GGamers\Desktop\FLC\hackhatons\lenta\AVITO"

# Модель и процессор
from transformers import BitsAndBytesConfig
   
quantization_config = BitsAndBytesConfig(load_in_4bit=True)
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    quantization_config=quantization_config,
    device_map="auto",
)

processor = AutoProcessor.from_pretrained(model_id)

img = Image.open("lenta_hack-as-branch\data\crop1.png")  # выберите локально загруженное изображение

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": img,
                "min_pixels": 4 * 28 * 28,
                "max_pixels": 1024 * 28 * 28,
            },
            {
                "type": "text",
                "text": """
                Напиши название товара, оно находится в верхней части слева
                Изучи ценник товара, твоя задача определить его
                название, цену без карты цена по карте
                , если есть какие-то дополнительные скидочные условия описать
                  так же их и найти артикул, перед артикулом стоит
                    знак _ так же есть штрихкод нужен его код"""
            }
        ],
    }
]

# Подготовка входа
chat_text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[chat_text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)

inputs = inputs.to("cuda")

# Генерация
generated_ids = model.generate(**inputs, max_new_tokens=256)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
response = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(response)
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\d'
# <>:20: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\GGamers\AppData\Local\Temp\ipykernel_23400\982824700.py:20: SyntaxWarning: invalid escape sequence '\d'
#   img = Image.open("lenta_hack-as-branch\data\crop1.png")  # выберите локально загруженное изображение
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 12
#       8 # Модель и процессор
#       9 from transformers import BitsAndBytesConfig
#      10
#      11 quantization_config = BitsAndBytesConfig(load_in_4bit=True)
# ---> 12 model = AutoModelForImageTextToText.from_pretrained(
#      13     model_id,
#      14     quantization_config=quantization_config,
#      15     device_map="auto",
#
# ...

# %%
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce RTX 5070
