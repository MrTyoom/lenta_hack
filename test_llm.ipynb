# %%
from LLMTEXT.product_matcher import find_top5_matches
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\GGamers\Desktop\FLC\hackhatons\lenta\VLM MODULE\vlm_select\25_12-20\25_12-20.xlsx")

# %%
df['raw_text']
# Out:
# 0     <0x0A>GRILL▁WINE▁<>▁295▁<>▁295▁<>▁-26%▁<>▁1234...
# 1     <0x0A>Без▁крема▁(Португалия)▁TRES▁ARCOS▁Томас▁...
# 2     <0x0A>Продукты_название<>Цена_без_карты<>Цена_...
# 3     <0x0A>Продукты_название<>Цена_без_карты<>Цена_...
# 4     <0x0A>Продукты_имен<>Цена_без_карты<>Цена_с_ка...
#                             ...
# 58    <0x0A>Продукт_название<>Цена_без_карты<>Цена_с...
# 59    <0x0A>Вина▁Баррос▁Таунси▁0.75л<>2831.99<>1799....
# 60    <0x0A>Винно▁крепленное▁ликерное▁ТИО▁ТОТО▁Опоро...
# 61    <0x0A>Продукты_название<>Цена_без_карты<>Цена_...
# 62    <0x0A>Винно▁крепленное▁ликерное▁KWV▁Классик▁Ко...
# Name: raw_text, Length: 63, dtype: str

# %%
data = find_top5_matches(df, ocr_col='raw_text')
# Out:
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 9390.32it/s]

# %%
data.to_excel('result.xlsx', index = False)
